# %% [markdown]
# #Imbalance in dataset:
#
# A dataset with an unequal class distribution
#
# -> Diabetes dataset , it would have 1000 data points of patients having diabetes and only few 100 data points of patients without diabetes...

# %%
import numpy as np
import pandas as pd

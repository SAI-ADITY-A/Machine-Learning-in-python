# %% [markdown]
# **API : Application Programming Interface**
#
# Sometimes to download and upload large files can be tiresome , so we use API's to directly access the data withou donwloading or anything

# %%
# importing the kagggle library
# !pip install kaggle

# %% [markdown]
# **First upload your .json file**

# %%
# configuring the path of kaggle.json
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# **Now we can import the earthquake dataset**

# %%
#API to fetch the dataset from kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
#  99% 2.26G/2.27G [00:26<00:00, 83.5MB/s]
# 100% 2.27G/2.27G [00:26<00:00, 91.8MB/s]

# %%
# now we can see all the files in the upload section but in .zip form
#extracting the zip file
from zipfile import ZipFile
dataset = '/content/LANL-Earthquake-Prediction.zip'

with ZipFile(dataset,'r') as zip:
    zip.extractall()
    print("the zip file is extracted")
# Out:
# the zip file is extracted

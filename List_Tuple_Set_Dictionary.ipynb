# %% [markdown]
# #Types of objects in python:
#
# 1.   Immutable Objects
# 2.   Mutable objects
#
# #Immutable Objects:
#
#
# 1.   int
# 2.   float
# 3. string
# 4. bool
# 5. tuple
#
# #Mutable objects:
#
#
#
# 1.   list
# 2.   set
# 3.dictionary

# %% [markdown]
# # **LISTS - should be stored in square brackets, can store multiple data** **points**

# %%
lis = [1,2,3,4,5,6]
print(lis)
type(lis)
# Out:
# [1, 2, 3, 4, 5, 6]
# list

# %%
ls = ["😂", 1, "hi", 6.3, True, 2>3, 1 + 3j]
print(ls)
# Out:
# ['😂', 1, 'hi', 6.3, True, False, (1+3j)]

# %%
ls.append("😊") # adds the new data at the end of the list
print(ls[7])
# Out:
# 😊

# %%
ls.append(6.3) # list allows to store duplicate values unlike sets
print(ls)
print(len(ls)) # size of the list
# Out:
# ['😂', 1, 'hi', 6.3, True, False, (1+3j), '😊', '😊', '😊', 6.3, 6.3]
# 12

# %%
print(ls)
del ls[3] # deleting an element
print(ls)
# Out:
# ['😂', 1, 'hi', 6.3, True, False, (1+3j), '😊', '😊', '😊', 6.3, 6.3]
# ['😂', 1, 'hi', True, False, (1+3j), '😊', '😊', '😊', 6.3, 6.3]

# %%
ls1 = [1,2,3,4]
ls2 = [5,6,7,8]
ls3 = ls1 + ls2
print(ls3)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# #**TUPLES: Immutable, they should be stored in rounded brackets (), it also allows to store multiple datatypes**

# %%
tup = (1,2,3,4)
print(tup)
type(tup)
# Out:
# (1, 2, 3, 4)
# tuple

# %%
myTup = ("Hi", 1, 6.9, "😁", 1==2)
print(myTup)
# Out:
# ('Hi', 1, 6.9, '😁', False)

# %%
myList = [1, 2, 3, 4, 5, 6, 7, 8]
newTup = tuple(myList)
print(newTup)
type(newTup)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)
# tuple

# %% [markdown]
# #**SET: Only stores unique elements, and should be stored using curly braces {}**

# %%
mySet = {1,2,4,5}
print(mySet)
type(mySet)
# Out:
# {1, 2, 4, 5}
# set

# %%
newList = [1,1,1,2,3,4,5,6]
newSet = set(newList)
print(newSet)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# #**DICTIONARY: contains a key value pair, stored in curly brackets**

# %%
dict = {'name': 'Aditya',
        'age' : 19,
        'roll' : 36,
        'country' : 'India'}
print(dict)
type(dict)
# Out:
# {'name': 'Aditya', 'age': 19, 'roll': 36, 'country': 'India'}
# dict

# %%
# we can call the value using the key in the dictionary
print(dict['name'])
print(dict['country'])
# Out:
# Aditya
# India

# %%
# doesn't allow duplicate values
dict1 = {'name': 'Aditya',
        'age' : 19,
        'roll' : 36,
        'country' : 'India',
        'name': 'Aditya'}
print(dict1)
# Out:
# {'name': 'Aditya', 'age': 19, 'roll': 36, 'country': 'India'}

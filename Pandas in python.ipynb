# %% [markdown]
# #PANDAS Library:
#
# Useful for Data processing and Analysis

# %% [markdown]
# **Pandas dataframe:**
# **Pandas dataframe is a two dimenssional tabular data structure with labelled axes (rows and columns) **

# %%
import pandas as pd
import numpy as np

# %%
boston_dataset = pd.read_csv('/content/Boston.csv')
# print(boston_dataset)
# using pandas functions
boston_dataset.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
boston_dataset.shape
# Out:
# (506, 15)

# %%
diabetes_df = pd.read_csv('/content/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# **Loading data from an excel file to a pandas dataframe:**

# %%
sample_df = pd.read_excel('/content/DATA test Aug 23 2023.xlsx')
sample_df.head()
# Out:
#   HM_TEMP CHARGE_HM CHARGE_SS CHARGE_IO HM_C HM_MN HM_P HM_S HM_SI TURET_WT_I  \
# 0      x1        x2        x3        x4   x5    x6   x7   x8    x9        x10
# 1    1341       138        17       2.4  4.3    11    6  042    81        147
# 2    1345       135        15       3.4  4.4    11    6  049    83        142
# 3    1383       135        14         3  4.3    11    6  043    56        141
# 4    1411       130        15         2  4.3    11    6  044    68        140
#
#   OPEN_TEMP
# 0         Y
# 1      1699
# 2      1728
# 3      1691
# 4      1736

# %%
sample_df.shape
# Out:
# (587, 11)

# %% [markdown]
# **Exporting a dataframe into a .csv file and .xslx file:**
#
# Eg: xyz_df.to_csv('file_name.csv')
#
# xyz_df.to_excel('file_name.xslx')

# %% [markdown]
# #**Creating a dataframe with random values**

# %%
random_df = pd.DataFrame(np.random.rand(10,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.955327  0.141168  0.297102  0.670178  0.914644  0.332478  0.721074
# 1  0.382949  0.191617  0.846427  0.534789  0.623422  0.083467  0.807342
# 2  0.803487  0.243485  0.643392  0.963619  0.204136  0.101643  0.338543
# 3  0.330741  0.074340  0.594625  0.803351  0.772659  0.987382  0.052675
# 4  0.709358  0.175941  0.893798  0.485895  0.666721  0.777929  0.121889
#
#           7         8         9
# 0  0.822203  0.820885  0.081450
# 1  0.513951  0.524777  0.844186
# 2  0.237980  0.262572  0.245184
# 3  0.040029  0.616934  0.493802
# 4  0.347659  0.147325  0.233734

# %%
random_df.shape
# Out:
# (10, 10)

# %% [markdown]
# **Inspecting a dataframe:**

# %%
# finding the no. of rows and columns
boston_dataset.shape
# Out:
# (506, 15)

# %%
# first 5 rows of a dataframe
boston_dataset.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
# last 5 rows of the dataframe
boston_dataset.tail()
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 501         502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9

# %%
# information about the dataframe
boston_dataset.info()
# Non-null count => the no. the missing values in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
# finding the no. of missing values in the dataframe
boston_dataset.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
#diabetes dataframe
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# counting the values based on the column name
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
# grouping the data based on the mean of the outcome
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# #**Statistical measures of the dataset:**

# %%
# count or no. of values in each
boston_dataset.count()
# Out:
# Unnamed: 0    506
# crim          506
# zn            506
# indus         506
# chas          506
# nox           506
# rm            506
# age           506
# dis           506
# rad           506
# tax           506
# ptratio       506
# black         506
# lstat         506
# medv          506
# dtype: int64

# %%
boston_dataset.min()
# Out:
# Unnamed: 0      1.00000
# crim            0.00632
# zn              0.00000
# indus           0.46000
# chas            0.00000
# nox             0.38500
# rm              3.56100
# age             2.90000
# dis             1.12960
# rad             1.00000
# tax           187.00000
# ptratio        12.60000
# black           0.32000
# lstat           1.73000
# medv            5.00000
# dtype: float64

# %%
boston_dataset.max()
# Out:
# Unnamed: 0    506.0000
# crim           88.9762
# zn            100.0000
# indus          27.7400
# chas            1.0000
# nox             0.8710
# rm              8.7800
# age           100.0000
# dis            12.1265
# rad            24.0000
# tax           711.0000
# ptratio        22.0000
# black         396.9000
# lstat          37.9700
# medv           50.0000
# dtype: float64

# %%
boston_dataset.mean()
# Out:
# Unnamed: 0    253.500000
# crim            3.613524
# zn             11.363636
# indus          11.136779
# chas            0.069170
# nox             0.554695
# rm              6.284634
# age            68.574901
# dis             3.795043
# rad             9.549407
# tax           408.237154
# ptratio        18.455534
# black         356.674032
# lstat          12.653063
# medv           22.532806
# dtype: float64

# %%
boston_dataset.std()
# Out:
# Unnamed: 0    146.213884
# crim            8.601545
# zn             23.322453
# indus           6.860353
# chas            0.253994
# nox             0.115878
# rm              0.702617
# age            28.148861
# dis             2.105710
# rad             8.707259
# tax           168.537116
# ptratio         2.164946
# black          91.294864
# lstat           7.141062
# medv            9.197104
# dtype: float64

# %%
# getting all the statistical measures in one go
boston_dataset.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# #**Manipulating a Dataframe:**

# %%
# adding a column
# boston_dataset['price'] = boston_dataset.target
# the no. of values should be same

# %%
# removing a row
boston_dataset.drop(index = 0, axis = 0)
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 1             2  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# 5             6  0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3
# ..          ...      ...  ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
# removing a column
boston_dataset.drop(columns = 'Unnamed: 0', axis = 1)
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# locating a row by it's index
boston_dataset.iloc[2]
# Out:
# Unnamed: 0      3.00000
# crim            0.02729
# zn              0.00000
# indus           7.07000
# chas            0.00000
# nox             0.46900
# rm              7.18500
# age            61.10000
# dis             4.96710
# rad             2.00000
# tax           242.00000
# ptratio        17.80000
# black         392.83000
# lstat           4.03000
# medv           34.70000
# Name: 2, dtype: float64

# %%
# locating a column
print(boston_dataset.iloc[:,1])  # first column
print(boston_dataset.iloc[:,-1]) # last column
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: crim, Length: 506, dtype: float64
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %% [markdown]
# **Correlation: How one variable changes w.r.t to each other**
#
#
#
# 1.   Positive
# 2.   Negative

# %%
boston_dataset.corr()
# example, medv(price) is negatively correlated with crime(crime value)
# Out:
#             Unnamed: 0      crim        zn     indus      chas       nox  \
# Unnamed: 0    1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736
# crim          0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972
# zn           -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604
# indus         0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651
# chas         -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203
# nox           0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000
# rm           -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188
# age           0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470
# dis          -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230
# rad           0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441
# tax           0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023
# ptratio       0.291074  0.289946 -0.391679  0.383248 -0.121515  0.188933
# ...
